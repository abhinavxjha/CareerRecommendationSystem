# %%
#import sys
#sys.path.append("../modules")
#from helpers import (
#    load_json,
#    get_required_skills,
#    load_courses,
#    career_selection,
#    course_recommendation,
#    skill_gap_analysis
#)

# %%
#import json

# %%
'''courses_data=load_courses('../data/courses.json')
required_skills_data=load_json("../data/careers.json")
selected_career=career_selection()
skills=input("Enter Your Skills :: ")
user_skills=skills.split()'''

# %%
'''required_skills = get_required_skills(required_skills_data, selected_career)
missing_skills=list(set(required_skills)-set(user_skills))
final_missing_skills=sorted(missing_skills)'''

'''required_skills=skill_gap_analysis(required_skills_data, selected_career, user_skills)'''

# %%
'''def fcourser_recommend(required_skills, courses_data):
    courses=course_recommendation(required_skills, courses_data)
    print("RECOMMENDED COURSES FOR YOUR MISSING SKILL","\n")
    for course in courses:
        print("Skill :", course["skill"])
        print("Course :", course["course"])
        print("Provider :", course["provider"])
        print("Link :", course["link"])
        print("-" * 50)'''
# Out:
# RECOMMENDED COURSES FOR YOUR MISSING SKILL
#
# Skill : SQL
# Course : SQL for Data Analytics
# Provider : CampusX
# Link : https://www.youtube.com/@campusx-official
# --------------------------------------------------
# Skill : SQL
# Course : Databases and SQL for Data Science
# Provider : Coursera
# Link : https://www.coursera.org/learn/sql-data-science
# --------------------------------------------------
# Skill : Power BI
# Course : Power BI Course
# Provider : CampusX
# Link : https://www.youtube.com/@campusx-official
# --------------------------------------------------
# Skill : Power BI
# Course : Power BI Desktop for Business Intelligence
# Provider : Udemy
# Link : https://www.udemy.com
# --------------------------------------------------

# %%
#fcourser_recommend(required_skills, courses_data)
