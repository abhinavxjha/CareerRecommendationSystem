# %% [markdown]
# PRIORITY WISE ROADMAP FOR MISSING SKILLS

# %%
'''import sys
sys.path.append("../modules")
from helpers import (
    load_json,
    get_required_skills,
    career_selection,
    values,
    course_recommendation,
    load_courses,
    skills_input,
    skill_gap_analysis
)'''

# %%
'''required_skills_data=load_json("../data/careers.json")
courses_data=load_courses('../data/courses.json')
selected_career=career_selection()
user_skills=skills_input()'''

# %%
'''mskills=skill_gap_analysis(required_skills_data, selected_career, user_skills)
courses=course_recommendation(mskills, courses_data)   #will go to notebook 9'''

# %%
'''def roadmap_generator(mskills, courses):
    roadmap={}
    for month, skill in enumerate(mskills, start=1):
        roadmap[f"Month {month}"]={"skill":skill}
        if month==3:
            break
    return roadmap'''

# %%
'''def final_roadmap():
    frmap=roadmap_generator(mskills, courses)
    for i,j in frmap.items():
        print(i ,"-", j)
        print("-" * 50)'''
# Out:
# Month 1 - {'skill': 'A/B Testing'}
# --------------------------------------------------
# Month 2 - {'skill': 'Big Data'}
# --------------------------------------------------
# Month 3 - {'skill': 'Data Wrangling'}
# --------------------------------------------------
